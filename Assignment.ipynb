# %%
#Question NUmber 1

# %%
name = "Ali"
age = 20 
city = "Karachi"
is_student = True 
print("Student Information")
print(name)
print(age)
print(city)
print(is_student)
# Out:
# Student Information
# Ali
# 20
# Karachi
# True

# %%
#Question Number 2 Total Marks

# %%
student_name = "Ali"
age = 20 
math = 85
english = 78
science = 90
attendence = 80
total_marks = math +english + science
print(math +english + science)
# Out:
# 253

# %%
#Question 3

# %%
average_marks = total_marks/3
print(253/3)
# Out:
# 84.33333333333333

# %%
# 4. Logical operators

# %%
is_eligible = (average_marks >= 50) and (attendence >= 75)
print("Is Student Eligible?:", is_eligible)
# Out:
# Is Student Eligible?: True
